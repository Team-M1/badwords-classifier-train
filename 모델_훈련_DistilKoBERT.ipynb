# %%
# !git clone https://github.com/Team-M1/badwords-classifier-train -b BM # 자기 브랜치 이름으로 변경
# %cd badwords-classifier-train
# !pip install -r requirements.txt
# Out:
# Cloning into 'badwords-classifier-train'...
# remote: Enumerating objects: 184, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 184 (delta 101), reused 94 (delta 18), pack-reused 0
# Receiving objects: 100% (184/184), 2.76 MiB | 17.79 MiB/s, done.
# Resolving deltas: 100% (101/101), done.
# /content/badwords-classifier-train
# Collecting datasets
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 7.7 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (0.10.0+cu102)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.9.0+cu102)
# Collecting torchmetrics
#   Downloading torchmetrics-0.5.1-py3-none-any.whl (282 kB)
#      |████████████████████████████████| 282 kB 55.2 MB/s
# Collecting transformers
#   Downloading transformers-4.10.0-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 62.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (1.1.5)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.4.5-py3-none-any.whl (919 kB)
#      |████████████████████████████████| 919 kB 64.2 MB/s
# Collecting sadice
#   Downloading sadice-0.1.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (0.22.2.post1)
# Collecting optuna
#   Downloading optuna-2.9.1-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 69.9 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (4.6.4)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (3.0.0)
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.8.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 74.3 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (1.19.5)
# Collecting huggingface-hub<0.1.0
#   Downloading huggingface_hub-0.0.16-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.5 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (0.70.12.2)
# Requirement already satisfied: tqdm>=4.42 in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (4.62.0)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 63.7 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (21.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets->-r requirements.txt (line 1)) (0.3.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets->-r requirements.txt (line 1)) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->-r requirements.txt (line 1)) (2021.5.30)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->-r requirements.txt (line 2)) (7.1.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 54.9 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 75.2 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 70.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r requirements.txt (line 5)) (2019.12.20)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 6)) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 6)) (1.15.0)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 75.7 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning->-r requirements.txt (line 7)) (2.6.0)
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 45.3 MB/s
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (0.4.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (3.3.4)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (1.39.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (1.34.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 7)) (3.1.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->-r requirements.txt (line 9)) (1.4.1)
# Collecting cliff
#   Downloading cliff-3.9.0-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 12.6 MB/s
# Collecting alembic
#   Downloading alembic-1.7.1-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 79.7 MB/s
# Collecting colorlog
#   Downloading colorlog-6.4.1-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna->-r requirements.txt (line 10)) (1.4.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna->-r requirements.txt (line 10)) (1.1.1)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 75.1 MB/s
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 70.9 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec>=2021.05.0->datasets->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna->-r requirements.txt (line 10)) (5.2.2)
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.9 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.6.0-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 79.9 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna->-r requirements.txt (line 10)) (2.1.0)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.1.2-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 74.7 MB/s
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.4.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 8.5 MB/s
# Collecting colorama>=0.3.7
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements.txt (line 10)) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna->-r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r requirements.txt (line 5)) (7.1.2)
# Building wheels for collected packages: future, pyperclip
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=e144ef02b7172b835e41ca948d571263e659d7284023e0c1526cb0244f8883bb
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11136 sha256=1ff780f7168ff5a526b32dd52fc6dedc446e4466d12a98e27f29903951709f94
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built future pyperclip
# Installing collected packages: multidict, yarl, pyperclip, pbr, colorama, async-timeout, stevedore, pyyaml, Mako, fsspec, cmd2, autopage, aiohttp, xxhash, torchmetrics, tokenizers, sacremoses, pyDeprecate, huggingface-hub, future, colorlog, cmaes, cliff, alembic, transformers, sadice, pytorch-lightning, optuna, datasets
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed Mako-1.1.5 aiohttp-3.7.4.post0 alembic-1.7.1 async-timeout-3.0.1 autopage-0.4.0 cliff-3.9.0 cmaes-0.8.2 cmd2-2.1.2 colorama-0.4.4 colorlog-6.4.1 datasets-1.11.0 fsspec-2021.8.1 future-0.18.2 huggingface-hub-0.0.16 multidict-5.1.0 optuna-2.9.1 pbr-5.6.0 pyDeprecate-0.3.1 pyperclip-1.8.2 pytorch-lightning-1.4.5 pyyaml-5.4.1 sacremoses-0.0.45 sadice-0.1.3 stevedore-3.4.0 tokenizers-0.10.3 torchmetrics-0.5.1 transformers-4.10.0 xxhash-2.0.2 yarl-1.6.3

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

path_to_drive = "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 시드 통일하기

# %%
import torch
from transformers import set_seed


set_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # 모델 불러오기

# %%
# 만약 ForSequenceClassification이 붙은 모델을 사용할 경우
model_config = {
    "num_labels": 3,
    "id2label": {0: 0, 1: 1, 2: 2},
    "label2id": {0: 0, 1: 1, 2: 2}
}

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 8.1 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %%
from transformers import DistilBertForSequenceClassification
from tokenization_kobert import KoBertTokenizer

model = DistilBertForSequenceClassification.from_pretrained("monologg/distilkobert", **model_config)
tokenizer = KoBertTokenizer.from_pretrained("monologg/kobert", model_max_length=512)

# model.save_pretrained("./model")
tokenizer.tokenize("안녕하세요. 오늘 날씨는 비가 계속 내리내요.")
# Out:
# Some weights of the model checkpoint at monologg/distilkobert were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at monologg/distilkobert and are newly initialized: ['classifier.weight', 'pre_classifier.bias', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'KoBertTokenizer'.
# ['▁안', '녕', '하세요', '.', '▁오늘', '▁날씨', '는', '▁비가', '▁계속', '▁내리', '내', '요', '.']

# %% [markdown]
# # 하이퍼 파라미터 설정

# %%
num_classes = 3

# 원하는 대로 고쳐서 사용
batch_size = 64
lr = 0.001
epochs = 150

# %%
# 옵티마이저와 스케줄러
# 원하는 대로 고쳐서 사용

# from torch.optim import AdamW
# from transformers import AdamW, get_linear_schedule_with_warmup


# LENGTH_OF_TRAIN_DATA = 40242
# num_training_steps = ((LENGTH_OF_TRAIN_DATA - 1) // batch_size + 1) * epochs
# optimizer = AdamW(model.parameters(), lr=lr)
# scheduler = get_linear_schedule_with_warmup(optimizer, int(num_training_steps * 0.1), num_training_steps)

# 만약 이 스케줄러를 사용할 경우,
# optimizer.step() 바로 다음에
# scheduler.step()을 호출해야 함

# %% [markdown]
# # f1 score 계산하기

# %%
# 1. torchmetrics 사용
# requirements에 넣어놨으니 따로 설치할 필요 없음

# from torchmetrics import F1


# f1_score = F1(num_classes=num_classes)

# # 검증 단계에서 사용
# for inputs, labels in val_loader:
#     # 대충 코드
#     output = model(inputs)  # 대충 아웃풋
#     pred = torch.argmax(output, dim=1)
#     batch_f1 = f1_score(pred, labels)
#     print(batch_f1)

# f1 = f1_score.compute()
# print(f1)

# %%
# 2. datasets 사용
# requirements에 넣어놨으니 따로 설치할 필요 없음
# 3번 사이킷런 사용법 쓰십시오 이건 좋지 않음

# from datasets import load_metric


# f1_score = load_metric("f1")

# for inputs, labels in val_loader:
#     # 대충 코드
#     output = model(inputs)
#     pred = torch.argmax(output, dim=1)
#     f1_score.add_batch(predictions=pred, references=labels)

# f1 = f1_score.compute()
# print(f1)

# %%
# 3. sklearn 사용
# from sklearn.metrics import accuracy_score, f1_score


# def compute_metrics(p):
#     pred, labels = p
#     pred = np.argmax(pred, axis=1)

#     accuracy = accuracy_score(y_true=labels, y_pred=pred)
#     f1 = f1_score(y_true=labels, y_pred=pred)

#     return {"accuracy": accuracy, "f1": f1}

# %% [markdown]
# # **훈련**

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score


def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    f1 = f1_score(y_true=labels, y_pred=pred, average="macro")

    return {"accuracy": accuracy, "f1": f1}

# %%
from data_loader import get_data_loaders


train_data, val_data, test_data = get_data_loaders(tokenizer, return_loader=False)
train_data = train_data.remove_columns("token_type_ids")
val_data = val_data.remove_columns("token_type_ids")
test_data = test_data.remove_columns("token_type_ids")
# Out:
# Using custom data configuration default-ab49892486032dec
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /root/.cache/huggingface/datasets/csv/default-ab49892486032dec/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff...
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-ab49892486032dec/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff. Subsequent calls will reuse this data.
#   0%|          | 0/40242 [00:00<?, ?ex/s]
#   0%|          | 0/4472 [00:00<?, ?ex/s]
#   0%|          | 0/5000 [00:00<?, ?ex/s]

# %%
model_name = "DistilKoBERT"
save_path = f"{path_to_drive}/{model_name}"

# %%
from transformers import TrainingArguments, EarlyStoppingCallback

from trainer import ImbalancedSamplerTrainer

args = TrainingArguments(
    output_dir=save_path,
    overwrite_output_dir=True,
    evaluation_strategy="steps",
    save_total_limit = 1,       # Only last 1 models are saved(best model). Older ones are deleted. ref= https://stackoverflow.com/questions/62525680/save-only-best-weights-with-huggingface-transformers
    load_best_model_at_end=True,  
    num_train_epochs=150,       # total number of training epochs
    seed=42,
    metric_for_best_model="f1",
    per_device_train_batch_size=16,     # batch size per device during training
    per_device_eval_batch_size=16,      # batch size for evaluation
    greater_is_better=True,
)

trainer = ImbalancedSamplerTrainer(
    model=model,
    args=args,
    train_dataset=train_data,
    eval_dataset=val_data,
    # tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=10)],
)
# Out:
# using `logging_steps` to initialize `eval_steps` to 500
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 40242
#   Num Epochs = 150
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 377400
#     <div>
#
#       <progress value='12500' max='377400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 12500/377400 56:34 < 27:31:51, 3.68 it/s, Epoch 4/150]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.058400</td>
#       <td>0.755087</td>
#       <td>0.879025</td>
#       <td>0.698302</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.060900</td>
#       <td>0.541887</td>
#       <td>0.907200</td>
#       <td>0.715388</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.077400</td>
#       <td>0.628495</td>
#       <td>0.896914</td>
#       <td>0.711174</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.084500</td>
#       <td>0.556547</td>
#       <td>0.903623</td>
#       <td>0.706909</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.067500</td>
#       <td>0.620065</td>
#       <td>0.886404</td>
#       <td>0.694968</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.055600</td>
#       <td>0.762236</td>
#       <td>0.882379</td>
#       <td>0.699415</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.069600</td>
#       <td>0.635581</td>
#       <td>0.900939</td>
#       <td>0.727934</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.069400</td>
#       <td>0.616048</td>
#       <td>0.901386</td>
#       <td>0.713330</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.063500</td>
#       <td>0.594271</td>
#       <td>0.919499</td>
#       <td>0.724746</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.044000</td>
#       <td>0.667975</td>
#       <td>0.911449</td>
#       <td>0.715195</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.054700</td>
#       <td>0.687572</td>
#       <td>0.896691</td>
#       <td>0.717561</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.056400</td>
#       <td>0.658644</td>
#       <td>0.906753</td>
#       <td>0.725105</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.051100</td>
#       <td>0.667722</td>
#       <td>0.894007</td>
#       <td>0.713189</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.052300</td>
#       <td>0.671744</td>
#       <td>0.906977</td>
#       <td>0.719266</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.050400</td>
#       <td>0.637030</td>
#       <td>0.909884</td>
#       <td>0.729238</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.054400</td>
#       <td>0.637575</td>
#       <td>0.893336</td>
#       <td>0.703165</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.091000</td>
#       <td>0.639415</td>
#       <td>0.904070</td>
#       <td>0.709406</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.086200</td>
#       <td>0.518037</td>
#       <td>0.916592</td>
#       <td>0.720650</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.083900</td>
#       <td>0.510324</td>
#       <td>0.915250</td>
#       <td>0.727297</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.068200</td>
#       <td>0.620182</td>
#       <td>0.894231</td>
#       <td>0.713196</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.074800</td>
#       <td>0.697066</td>
#       <td>0.890429</td>
#       <td>0.706062</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.064800</td>
#       <td>0.701996</td>
#       <td>0.905188</td>
#       <td>0.719950</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.071100</td>
#       <td>0.558118</td>
#       <td>0.914803</td>
#       <td>0.711391</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.063600</td>
#       <td>0.604794</td>
#       <td>0.915474</td>
#       <td>0.707478</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.059100</td>
#       <td>0.657605</td>
#       <td>0.916816</td>
#       <td>0.708693</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-2500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-1000] due to args.save_total_limit
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-4500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-5500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-6500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-3500] due to args.save_total_limit
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-8500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-9500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-10500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-12000
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-12000/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-12000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-11500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4472
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-12500
# Configuration saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-12500/config.json
# Model weights saved in /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-12500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-12000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/drive/MyDrive/Colab Notebooks/DistilKoBERT/checkpoint-7500 (score: 0.7292381108861438).
# TrainOutput(global_step=12500, training_loss=0.06531183837890625, metrics={'train_runtime': 3395.0589, 'train_samples_per_second': 1777.966, 'train_steps_per_second': 111.162, 'total_flos': 1.3425826250170368e+16, 'train_loss': 0.06531183837890625, 'epoch': 4.97})
