# %% [markdown]
# # 시드 통일하기

# %%
import torch
from transformers import set_seed


set_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # 모델 불러오기

# %%
model_config = {
    "num_labels": 3,
    "id2label": {0: 0, 1: 1, 2: 2},
    "label2id": {0: 0, 1: 1, 2: 2}
}

# %%
# from transformers import KoBertForSequenceClassification
# from tokenization_kobert import KoBertTokenizer


# model = KoBertForSequenceClassification.from_pretrained("monologg/kobert-discriminator", **model_config)
# tokenizer = KoBertTokenizer.from_pretrained("monologg/kobert-discriminator", model_max_length=512)

from transformers import ElectraForSequenceClassification, ElectraTokenizer


model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator", **model_config)
tokenizer = ElectraTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator", model_max_length=512)
# Out:
# Some weights of the model checkpoint at monologg/koelectra-base-v3-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # 하이퍼 파라미터 설정

# %%
num_classes = 3

# 원하는 대로 고쳐서 사용
batch_size = 64
lr = 5e-5  # 0.00005
epochs = 150

# %%
# 옵티마이저와 스케줄러
# 원하는 대로 고쳐서 사용

# from torch.optim import AdamW
# from transformers import AdamW, get_linear_schedule_with_warmup


# LENGTH_OF_TRAIN_DATA = 40242
# num_training_steps = ((LENGTH_OF_TRAIN_DATA - 1) // batch_size + 1) * epochs
# optimizer = AdamW(model.parameters(), lr=lr)
# scheduler = get_linear_schedule_with_warmup(optimizer, int(num_training_steps * 0.1), num_training_steps)

# 만약 이 스케줄러를 사용할 경우,
# optimizer.step() 바로 다음에
# scheduler.step()을 호출해야 함

# %% [markdown]
# # f1 score 계산하기

# %%
# 1. torchmetrics 사용
# requirements에 넣어놨으니 따로 설치할 필요 없음

# from torchmetrics import F1


# f1_score = F1(num_classes=num_classes)

# # 검증 단계에서 사용
# for inputs, labels in val_loader:
#     # 대충 코드
#     output = model(inputs)  # 대충 아웃풋
#     pred = torch.argmax(output, dim=1)
#     batch_f1 = f1_score(pred, labels)
#     print(batch_f1)

# f1 = f1_score.compute()
# print(f1)

# %%
# 2. datasets 사용
# requirements에 넣어놨으니 따로 설치할 필요 없음

# from datasets import load_metric


# f1_score = load_metric("f1")

# for inputs, labels in val_loader:
#     # 대충 코드
#     output = model(inputs)
#     pred = torch.argmax(output, dim=1)
#     f1_score.add_batch(predictions=pred, references=labels)

# f1 = f1_score.compute()
# print(f1)

# %% [markdown]
# # 훈련

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score


def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    f1 = f1_score(y_true=labels, y_pred=pred, average="macro")

    return {"accuracy": accuracy, "f1": f1}

# %%
from data_loader import get_data_loaders


train_data, val_data, test_data = get_data_loaders(tokenizer, return_loader=False)
# Out:
# Using custom data configuration default-eafb513e725dbeca
# Reusing dataset csv (C:\Users\cglab\.cache\huggingface\datasets\csv\default-eafb513e725dbeca\0.0.0\9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff)
# Loading cached processed dataset at C:\Users\cglab\.cache\huggingface\datasets\csv\default-eafb513e725dbeca\0.0.0\9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff\cache-d815bbee38dcbc26.arrow
# Loading cached processed dataset at C:\Users\cglab\.cache\huggingface\datasets\csv\default-eafb513e725dbeca\0.0.0\9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff\cache-5c9fdd80709ca508.arrow
# Loading cached processed dataset at C:\Users\cglab\.cache\huggingface\datasets\csv\default-eafb513e725dbeca\0.0.0\9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff\cache-60328c4920383600.arrow

# %%
model_name = "KoELECTRA_base_v3_datav2"
save_path = f"{model_name}"

# %%
from transformers import TrainingArguments, EarlyStoppingCallback

from trainer import ImbalancedSamplerTrainer


args = TrainingArguments(
    output_dir=save_path,
    overwrite_output_dir=True,
    evaluation_strategy="steps",
    num_train_epochs=150,
    logging_steps=1000,
    save_steps=1000,
    seed=42,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    warmup_ratio=0.1,
    adafactor=True,
    lr_scheduler_type="cosine_with_restarts",
    learning_rate=1e-4,
)

trainer = ImbalancedSamplerTrainer(
    model=model,
    args=args,
    train_dataset=train_data,
    eval_dataset=val_data,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=20)],
)

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 45154
#   Num Epochs = 150
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 423450
#     <div>
#
#       <progress value='34000' max='423450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 34000/423450 6:19:35 < 72:28:17, 1.49 it/s, Epoch 12/150]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>1.043100</td>
#       <td>0.813652</td>
#       <td>0.762654</td>
#       <td>0.443088</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.700400</td>
#       <td>0.365383</td>
#       <td>0.874053</td>
#       <td>0.637602</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.427100</td>
#       <td>0.360210</td>
#       <td>0.868274</td>
#       <td>0.676597</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.315000</td>
#       <td>0.295772</td>
#       <td>0.901554</td>
#       <td>0.718292</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.231800</td>
#       <td>0.265334</td>
#       <td>0.919291</td>
#       <td>0.749149</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.199700</td>
#       <td>0.350936</td>
#       <td>0.912714</td>
#       <td>0.745613</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.186600</td>
#       <td>0.302968</td>
#       <td>0.918693</td>
#       <td>0.745362</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.163600</td>
#       <td>0.405137</td>
#       <td>0.911120</td>
#       <td>0.757225</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.143000</td>
#       <td>0.449312</td>
#       <td>0.910323</td>
#       <td>0.743393</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.130500</td>
#       <td>0.373581</td>
#       <td>0.928059</td>
#       <td>0.758698</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.117700</td>
#       <td>0.553718</td>
#       <td>0.901156</td>
#       <td>0.730960</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.120500</td>
#       <td>0.510214</td>
#       <td>0.910721</td>
#       <td>0.735983</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.106000</td>
#       <td>0.374886</td>
#       <td>0.923475</td>
#       <td>0.766723</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.106600</td>
#       <td>0.318547</td>
#       <td>0.938820</td>
#       <td>0.774413</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.094900</td>
#       <td>0.465325</td>
#       <td>0.928059</td>
#       <td>0.741334</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.086200</td>
#       <td>0.387188</td>
#       <td>0.935632</td>
#       <td>0.750770</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.085800</td>
#       <td>0.490694</td>
#       <td>0.921881</td>
#       <td>0.754384</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.086100</td>
#       <td>0.412461</td>
#       <td>0.934037</td>
#       <td>0.747057</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.079900</td>
#       <td>0.480801</td>
#       <td>0.931447</td>
#       <td>0.747481</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.078900</td>
#       <td>0.455830</td>
#       <td>0.930650</td>
#       <td>0.757879</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.078400</td>
#       <td>0.397726</td>
#       <td>0.932842</td>
#       <td>0.754828</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.074300</td>
#       <td>0.472296</td>
#       <td>0.928258</td>
#       <td>0.744262</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.079000</td>
#       <td>0.429406</td>
#       <td>0.931447</td>
#       <td>0.756603</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.065200</td>
#       <td>0.410803</td>
#       <td>0.931447</td>
#       <td>0.746677</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.069900</td>
#       <td>0.471131</td>
#       <td>0.933838</td>
#       <td>0.748148</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.063900</td>
#       <td>0.417412</td>
#       <td>0.938023</td>
#       <td>0.751742</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.055700</td>
#       <td>0.462502</td>
#       <td>0.937625</td>
#       <td>0.756753</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.063000</td>
#       <td>0.494742</td>
#       <td>0.936827</td>
#       <td>0.752338</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.063600</td>
#       <td>0.473320</td>
#       <td>0.935233</td>
#       <td>0.739187</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.067800</td>
#       <td>0.472866</td>
#       <td>0.939418</td>
#       <td>0.771741</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.062800</td>
#       <td>0.426153</td>
#       <td>0.939020</td>
#       <td>0.769340</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.059400</td>
#       <td>0.492752</td>
#       <td>0.935034</td>
#       <td>0.763847</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.219000</td>
#       <td>0.475071</td>
#       <td>0.917497</td>
#       <td>0.704019</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.088500</td>
#       <td>0.470170</td>
#       <td>0.921084</td>
#       <td>0.730897</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-1000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-1000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-2000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-2000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-3000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-3000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-3000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-4000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-4000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-4000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-5000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-5000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-5000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-6000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-6000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-6000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-7000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-7000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-7000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-8000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-8000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-8000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-9000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-9000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-9000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-10000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-10000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-10000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-11000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-11000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-11000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-12000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-12000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-12000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-13000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-13000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-13000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-14000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-14000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-14000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-15000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-15000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-15000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-16000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-16000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-16000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-17000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-17000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-17000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-18000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-18000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-18000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-19000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-19000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-19000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-20000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-20000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-20000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-21000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-21000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-21000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-22000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-22000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-22000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-23000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-23000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-23000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-24000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-24000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-24000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-25000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-25000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-25000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-26000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-26000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-26000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-27000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-27000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-27000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-28000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-28000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-28000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-29000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-29000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-29000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-30000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-30000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-30000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-31000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-31000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-31000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-32000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-32000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-32000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-33000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-33000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-33000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 5018
#   Batch size = 16
# Saving model checkpoint to KoELECTRA_base_v3_datav2\checkpoint-34000
# Configuration saved in KoELECTRA_base_v3_datav2\checkpoint-34000\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\checkpoint-34000\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from KoELECTRA_base_v3_datav2\checkpoint-14000 (score: 0.7744125160674633).
# TrainOutput(global_step=34000, training_loss=0.1651127061282887, metrics={'train_runtime': 22777.24, 'train_samples_per_second': 297.363, 'train_steps_per_second': 18.591, 'total_flos': 1.430894961898537e+17, 'train_loss': 0.1651127061282887, 'epoch': 12.04})

# %%
trainer.save_model(output_dir=save_path)
# Out:
# Saving model checkpoint to KoELECTRA_base_v3_datav2
# Configuration saved in KoELECTRA_base_v3_datav2\config.json
# Model weights saved in KoELECTRA_base_v3_datav2\pytorch_model.bin

# %%
trainer.save_state()
